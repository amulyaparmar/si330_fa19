# %% [markdown]
# # Exercise 1
# Given a dataset called run.csv which contains sensor data of my running over time, resample this dataset to
# one second resolution then plot a 5 minute rolling average of the heart rate data.
#
# *Only if you want to geek out: If you want a challenge, my answer was 119 characters long and one line. Can you come up with something smaller?*

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
df=pd.read_csv("datasets/run.csv")

# %%
df.set_index(pd.to_datetime(df["timestamp"]))["heart_rate"].resample("1S").fillna(method="ffill").rolling(5*60,min_periods=1).apply(np.mean).plot()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   """Entry point for launching an IPython kernel.

# %%
df.set_index(pd.to_datetime(df["timestamp"]))["heart_rate"].resample("1S").fillna(method="ffill").rolling(60*5).apply(np.mean).plot()
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Currently, 'apply' passes the values as ndarrays to the applied function. In the future, this will change to passing it as Series objects. You need to specify 'raw=True' to keep the current behaviour, and you can pass 'raw=False' to silence this warning
#   """Entry point for launching an IPython kernel.
